# %% [markdown]
# # Tensorflow + Horovod + Keras + Azure Batch AI

# %% [markdown]
# ## Introduction
#
# This recipe shows how to run [Horovod](https://github.com/uber/horovod) distributed training framework using Batch AI.
#
# Currently Batch AI has no native support for Horovod framework, but it's easy to run it using customtoolkit and job preparation command line.
#
#
# ## Details
#
# - Standard Horovod [tensorflow_mnist.py](https://github.com/uber/horovod/blob/v0.9.10/examples/tensorflow_mnist.py) example will be used;
# - tensorflow_mnist.py downloads training data on its own during execution;
# - The job will be run on standard tensorflow container tensorflow/tensorflow:1.1.0-gpu;
# - Horovod framework will be installed in the container using job preparation command line. Note, you can build your own docker image containing tensorflow and horovod instead.
# - Standard output of the job will be stored on Azure File Share.

# %% [markdown]
# ## Instructions
#
# ### Install Dependencies and Create Configuration file.
# Follow [instructions](/recipes) to install all dependencies and create configuration file.

# %% [markdown]
# ### Read Configuration and Create Batch AI client

# %%
from __future__ import print_function

import time
from datetime import datetime
import os
import sys
import zipfile

from azure.storage.file import FileService, FilePermissions
import azure.mgmt.batchai.models as models

# utilities.py contains helper functions used by different notebooks
sys.path.append('./')
import utilities

cfg = utilities.Configuration('configuration.json')
client = utilities.create_batchai_client(cfg)

# %% [markdown]
# ### Create File Share
#
# For this example we will create a new File Share with name `batchaisample` under your storage account. This share will be populated with sample scripts and will contain job's output.
#
# **Note** You don't need to create new file share for every cluster. We are doing this in this sample to simplify resource management for you.

# %%
azure_file_share_name = 'batchai35'
service = FileService(cfg.storage_account_name, cfg.storage_account_key)
service.create_share(azure_file_share_name, fail_on_exist=False)
# Out:
# True

# %% [markdown]
# ### Configure Compute Cluster
#
# - For this example we will use a gpu cluster of `STANDARD_NC6` nodes. Number of nodes in the cluster is configured with `nodes_count` variable;
# - We will mount file share at folder with name `external`. Full path of this folder on a computer node will be `$AZ_BATCHAI_MOUNT_ROOT/external`;
# - We will call the cluster `nc6`.
#
#
# So, the cluster will have the following parameters:

# %%
azure_file_share = 'external'
nodes_count = 2
cluster_name = 'nc6'

volumes = models.MountVolumes(
    azure_file_shares=[
        models.AzureFileShareReference(
            account_name=cfg.storage_account_name,
            credentials=models.AzureStorageCredentialsInfo(
                account_key=cfg.storage_account_key),
            azure_file_url = 'https://{0}.file.core.windows.net/{1}'.format(
                cfg.storage_account_name, azure_file_share_name),
            relative_mount_path=azure_file_share)
    ]
)

parameters = models.ClusterCreateParameters(
    location=cfg.location,
    vm_size="STANDARD_NC6",
    virtual_machine_configuration=models.VirtualMachineConfiguration(
        image_reference=models.ImageReference(
            publisher="microsoft-ads",
            offer="linux-data-science-vm-ubuntu",
            sku="linuxdsvmubuntu",
            version="latest")),
    scale_settings=models.ScaleSettings(
        manual=models.ManualScaleSettings(target_node_count=nodes_count)
    ),
    node_setup=models.NodeSetup(
        mount_volumes=volumes
    ),
    user_account_settings=models.UserAccountSettings(
        admin_user_name=cfg.admin,
        admin_user_password=cfg.admin_password,
        admin_user_ssh_public_key=cfg.admin_ssh_key
    )
)

# %% [markdown]
# ### Create Compute Cluster

# %%
_ = client.clusters.create(cfg.resource_group, cluster_name, parameters)

# %% [markdown]
# ### Monitor Cluster Creation
#
# utilities.py contains a helper function allowing to wait for the cluster to become available - all nodes are allocated and finished preparation.

# %%
cluster = client.clusters.get(cfg.resource_group, cluster_name)
utilities.print_cluster_status(cluster)
# Out:
# Cluster state: AllocationState.steady Target: 2; Allocated: 2; Idle: 2; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0

# %% [markdown]
# ### Deploy Sample Script and Configure the Input Directories

# %% [markdown]
# - Create a folder in the file share and upload the sample script to it.

# %%
script_directory = 'trainall_script'
#script_file = 'GloveBidirectionalLSTM_v3_1_2host.py'
script_file = 'BidirectionalLSTM_v2_1_2host.py'

#dataset_file1 = 'glove.6B.100d.txt'
#dataset_file2 = 'labeledTrainData.tsv'

service = FileService(cfg.storage_account_name, cfg.storage_account_key)
service.create_directory(
    azure_file_share_name, script_directory, fail_on_exist=False)

#Script file
service.create_file_from_path(
    azure_file_share_name, script_directory, script_file, script_file)

#Dataset file
#service.create_file_from_path(
#    azure_file_share_name, script_directory, dataset_file1, dataset_file1)
#service.create_file_from_path(
#    azure_file_share_name, script_directory, dataset_file2, dataset_file2)
# Out:
# Client-Request-ID=3aa14334-02b8-11e8-b1eb-5c514f38ccef Retry policy did not allow for a retry: Server-Timestamp=Fri, 26 Jan 2018 16:44:53 GMT, Server-Request-ID=eab51833-001a-012e-0fc4-962021000000, HTTP status code=409, Exception=The specified resource already exists.<?xml version="1.0" encoding="utf-8"?><Error><Code>ResourceAlreadyExists</Code><Message>The specified resource already exists.RequestId:eab51833-001a-012e-0fc4-962021000000Time:2018-01-26T16:44:54.0732401Z</Message></Error>.

# %% [markdown]
# - The job needs to know where to find train_mnist.py script (the chainer will download MNIST dataset on its own). So, we will configure an input directory for the script:

# %%
input_directories = [
    models.InputDirectory(
        id='SCRIPTS',
        path='$AZ_BATCHAI_MOUNT_ROOT/{0}/{1}'.format(azure_file_share, script_directory))
]

# %% [markdown]
# The job will be able to reference those directories using ```$AZ_BATCHAI_INPUT_SCRIPT``` environment variable.

# %% [markdown]
# ### Configure Output Directories
# We will store standard and error output of the job in File Share:

# %%
std_output_path_prefix = "$AZ_BATCHAI_MOUNT_ROOT/{0}".format(azure_file_share)

# %% [markdown]
# ### Configure Job
#
# - Will use configured previously input and output directories;
# - We will use custom toolkit job to run tensorflow_mnist.py on multiple nodes (use node_count parameter to specify number of nodes). Note, Batch AI will create a hostfile for the job, it can be found via ```$AZ_BATCHAI_MPI_HOST_FILE``` environment variable;
# - Horovod framework will be installed by job preparation command line;
# - Will output standard output and error streams to file share.
#
# You can delete ```container_settings``` from the job definition to run the job directly on host DSVM.

# %%
job_name = datetime.utcnow().strftime("horovod_keras_%m_%d_%Y_%H%M%S")
parameters = models.job_create_parameters.JobCreateParameters(
     location=cfg.location,
     cluster=models.ResourceId(cluster.id),
     node_count=nodes_count,
     input_directories=input_directories,
     std_out_err_path_prefix=std_output_path_prefix,
     container_settings=models.ContainerSettings(
         models.ImageSourceRegistry(image='tensorflow/tensorflow:1.4.0-gpu')),
     job_preparation=models.JobPreparation(
         command_line="apt update; apt install mpi-default-dev mpi-default-bin -y; pip install horovod; pip install keras; pip install bs4"),
     custom_toolkit_settings = models.CustomToolkitSettings(
         command_line='mpirun -mca btl_tcp_if_exclude docker0,lo --allow-run-as-root --hostfile $AZ_BATCHAI_MPI_HOST_FILE python $AZ_BATCHAI_INPUT_SCRIPTS/'+script_file))

# %% [markdown]
# ### Create a training Job and wait for Job completion

# %%
_ = client.jobs.create(cfg.resource_group, job_name, parameters)
print('Created Job: {}'.format(job_name))
# Out:
# Created Job: horovod_keras_01_26_2018_164508

# %% [markdown]
# ### Wait for Job to Finish
# The job will start running when the cluster will have enought idle nodes. The following code waits for job to start running printing the cluster state. During job run, the code prints current content of stderr.txt.
#
# **Note** Execution may take several minutes to complete.

# %%
utilities.wait_for_job_completion(client, cfg.resource_group, job_name, cluster_name, 'stdouterr', 'stderr.txt')
# Out:
# Cluster state: AllocationState.steady Target: 2; Allocated: 2; Idle: 2; Unusable: 0; Running: 0; Preparing: 0; Leaving: 0
# Job state: running ExitCode: None
# Waiting for job output to become available...
# Unexpected end of /proc/mounts line `overlay / overlay rw,relatime,lowerdir=/data/docker/overlay2/l/JSVFG6PRVBIRXJZ7ER5G4ZRWCM:/data/docker/overlay2/l/MTHYOXWRTP6JWSQLKBJDX6ZCG4:/data/docker/overlay2/l/BYWBM3MZXE3PEGJH2ROOOIEIAO:/data/docker/overlay2/l/EZVHUJZRPK46CSLFTFCFHU4K4D:/data/docker/overlay2/l/PMVJST7AYQ7TYB3RC7S7ECQB2E:/data/docker/overlay2/l/N6AEVBXOIEFOFGRJTKGZWJSXSL:/data/docker/overlay2/l/CPZIUJO6VVPA7W2DJM3TT6FSEY:/data/docker/overlay2/l/WUEAYMSG4V5QBLYLLDS75TD2QV:/data/docker/overlay2/l/DT33OWB23UIVK7C64UFZETWM3L:/data/docker/'
# Unexpected end of /proc/mounts line `overlay2/l/GGUVLW3G546SWQONNP5UPQGRFG:/data/docker/overlay2/l/FLLABMSE4XTXRZA65536CHOYRV:/data/docker/overlay2/l/7RXOBFEMW5Q55W5NT26DISZADX:/data/docker/overlay2/l/UVZL675ITV42SVPFFYOEIBVWIN:/data/docker/overlay2/l/ZCDOD2JBPQVFOBLIBLYELCUVMU:/data/docker/overlay2/l/MKYFR324E4KSFYFFQAIIWLJIKV:/data/docker/overlay2/l/TAH3NE6KYXPC6N6ZYUVAAXL3VM:/data/docker/overlay2/l/4GFKEW2R4HFJ2LOZQXSJ2J46AS:/data/docker/overlay2/l/TLFZWOYGLW7HPJJFENG3YE3OJB:/data/docker/overlay2/l/TGQHYMCCKIWNEE4LHLTBB6PVHD,upperdir=/data'
# Warning: Permanently added '[10.0.0.5]:23' (ECDSA) to the list of known hosts.
# Unexpected end of /proc/mounts line `overlay / overlay rw,relatime,lowerdir=/data/docker/overlay2/l/SHEHNWK3RPCW233QAWV2UN2Y5X:/data/docker/overlay2/l/ZZKFTBKRF4MU6BLK6IDNSOVKWG:/data/docker/overlay2/l/5WCCLGINUKUSNHTDDOPV2ZTS7G:/data/docker/overlay2/l/ODIEB6HPD44NIQ7LXI2YOQXJA6:/data/docker/overlay2/l/SXXW26YUNOXUY4D64KVYL3KQ5Y:/data/docker/overlay2/l/CYC2TH42QD423V4QWWTNDAEP37:/data/docker/overlay2/l/WI47UKCGF5V3FWHIIMMIVSBAZL:/data/docker/overlay2/l/2T3QLKWPBBKLEOQUHNL4Y5V6ZN:/data/docker/overlay2/l/R5NU57ERGXCJPZRUBB5YWAZ53U:/data/docker/'
# Unexpected end of /proc/mounts line `overlay2/l/EHO4XGFQYT2UKWR36H7ROIVVTZ:/data/docker/overlay2/l/PFUZK4LSCMK2LFMXPCI5TV4KK3:/data/docker/overlay2/l/VUZ6TW6WBVGEOBQASF5TNJIH3D:/data/docker/overlay2/l/JMV3HMF356AN2X7D4EOS4VCNKV:/data/docker/overlay2/l/TCGO7IEBBLFWJQEOMW4ZWYIKSS:/data/docker/overlay2/l/HC2GT4HZGU7W7E6PRWWTOZS4LC:/data/docker/overlay2/l/LQLPGUJELE5CXIX34LUYCY34AS:/data/docker/overlay2/l/4DEKYWDXEKVFAAJE7Y6J6MCDLL:/data/docker/overlay2/l/UKQHFTQS7FERU75QECSNFFTNMS:/data/docker/overlay2/l/WOREJ4I5MKOG7GJJRBQIBINDV3,upperdir=/data'
# Using TensorFlow backend.
# Using TensorFlow backend.
# 2018-01-26 16:52:50.068302: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-01-26 16:52:50.060574: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-01-26 16:52:50.385217: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0d88:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-01-26 16:52:50.385297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1120] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: Tesla K80, pci bus id: 0d88:00:00.0, compute capability: 3.7)
# 2018-01-26 16:52:50.388478: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: ef38:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-01-26 16:52:50.388521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1120] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: Tesla K80, pci bus id: ef38:00:00.0, compute capability: 3.7)
# [a3a674c94cc940d0924b1b23aa99bc77000000:01217] 1 more process has sent help message help-mpi-btl-base.txt / btl:no-nics
# [a3a674c94cc940d0924b1b23aa99bc77000000:01217] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# Job state: succeeded ExitCode: 0

# %% [markdown]
# ### Download stdout.txt and stderr.txt files for the Job and job preparation command

# %%
files = client.jobs.list_output_files(cfg.resource_group, job_name, models.JobsListOutputFilesOptions("stdOuterr")) 
for file in list(files):
    utilities.download_file(file.download_url, file.name)
print("All files Downloaded")
# Out:
# Downloading https://aitrainigstorage.file.core.windows.net/batchai35/1aa15964-43e9-4fab-9be5-81abdcb9c8d1/holkrazure/jobs/horovod_keras_01_26_2018_164508/1c0b7739-f8de-4f22-9880-a6e0219adaaf/stderr-job_prep-tvm-1392786932_1-20180126t163607z.txt?sv=2016-05-31&sr=f&sig=XmDM0gQ0zwnwbjwOnjf86sOSIpO5uxH5dWKg7tFByu4%3D&se=2018-01-26T18%3A15%3A33Z&sp=rl ...Done
# Downloading https://aitrainigstorage.file.core.windows.net/batchai35/1aa15964-43e9-4fab-9be5-81abdcb9c8d1/holkrazure/jobs/horovod_keras_01_26_2018_164508/1c0b7739-f8de-4f22-9880-a6e0219adaaf/stderr-job_prep-tvm-1392786932_2-20180126t163607z.txt?sv=2016-05-31&sr=f&sig=Z4WB7%2FBgiMH%2BDG5z85fBeZUzxKFN3GUrzBpjP6K0ko8%3D&se=2018-01-26T18%3A15%3A33Z&sp=rl ...Done
# Downloading https://aitrainigstorage.file.core.windows.net/batchai35/1aa15964-43e9-4fab-9be5-81abdcb9c8d1/holkrazure/jobs/horovod_keras_01_26_2018_164508/1c0b7739-f8de-4f22-9880-a6e0219adaaf/stderr.txt?sv=2016-05-31&sr=f&sig=Uv%2FSXuJOHpbrq3SM8%2By4XRESng7JyYiWMOkVTciMfO4%3D&se=2018-01-26T18%3A15%3A33Z&sp=rl ...Done
# Downloading https://aitrainigstorage.file.core.windows.net/batchai35/1aa15964-43e9-4fab-9be5-81abdcb9c8d1/holkrazure/jobs/horovod_keras_01_26_2018_164508/1c0b7739-f8de-4f22-9880-a6e0219adaaf/stdout-job_prep-tvm-1392786932_1-20180126t163607z.txt?sv=2016-05-31&sr=f&sig=JDiaEmHG58wdgAfzvnHkJXaWRh6x9TlkYM5sBEEdUbk%3D&se=2018-01-26T18%3A15%3A33Z&sp=rl ...Done
# Downloading https://aitrainigstorage.file.core.windows.net/batchai35/1aa15964-43e9-4fab-9be5-81abdcb9c8d1/holkrazure/jobs/horovod_keras_01_26_2018_164508/1c0b7739-f8de-4f22-9880-a6e0219adaaf/stdout-job_prep-tvm-1392786932_2-20180126t163607z.txt?sv=2016-05-31&sr=f&sig=WedTM1meuq7Hcm55MDeV0Hp14qkQ1MF7zYljGJ9kioY%3D&se=2018-01-26T18%3A15%3A33Z&sp=rl ...Done
# Downloading https://aitrainigstorage.file.core.windows.net/batchai35/1aa15964-43e9-4fab-9be5-81abdcb9c8d1/holkrazure/jobs/horovod_keras_01_26_2018_164508/1c0b7739-f8de-4f22-9880-a6e0219adaaf/stdout.txt?sv=2016-05-31&sr=f&sig=9KT4CSzddH5icRnNoUVjqB3jxEaLhCH%2FRt3HfFie1dM%3D&se=2018-01-26T18%3A15%3A33Z&sp=rl ...Done
# All files Downloaded

# %%
print('stdout.txt content:')
with open('stdout.txt') as f:
    print(f.read())

print('stderr.txt content:')
with open('stderr.txt') as f:
    print(f.read())
# Out:
# stdout.txt content:
# --------------------------------------------------------------------------
# [[13183,1],1]: A high-performance Open MPI point-to-point messaging module
# was unable to find any relevant network interfaces:
#
# Module: OpenFabrics (openib)
#   Host: d7a020c29eb74b5aa6c9b6c5b2279fc6000001
#
# Another transport will be used instead, although this may result in
# lower performance.
# --------------------------------------------------------------------------
# Loading data...
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# Loading data...
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# Loading data...
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# Loading data...
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
#
#    16384/17464789 [..............................] - ETA: 3s
#    16384/17464789 [..............................] - ETA: 0s
#    16384/17464789 [..............................] - ETA: 0s
#  1859584/17464789 [==>...........................] - ETA: 0s
#  1859584/17464789 [==>...........................] - ETA: 0s
#  1294336/17464789 [=>............................] - ETA: 0s
# 11698176/17464789 [===================>..........] - ETA: 0s
#  8634368/17464789 [=============>................] - ETA: 0s
#  9691136/17464789 [===============>..............] - ETA: 0s
# 16998400/17464789 [============================>.] - ETA: 0s
# 17465344/17464789 [==============================] - 0s 0us/step
#
# 17473536/17464789 [==============================] - 0s 0us/step
#
# 16302080/17464789 [===========================>..] - ETA: 0s
# 16842752/17464789 [===========================>..] - ETA: 0s
# 17465344/17464789 [==============================] - 0s 0us/step
#
# 17473536/17464789 [==============================] - 0s 0us/step
#
# 17465344/17464789 [==============================] - 0s 0us/step
#
# 17473536/17464789 [==============================] - 0s 0us/step
#
#    16384/17464789 [..............................] - ETA: 0s
#    65536/17464789 [..............................] - ETA: 14s
#  5898240/17464789 [=========>....................] - ETA: 0s
# 17465344/17464789 [==============================] - 0s 0us/step
#
# 17473536/17464789 [==============================] - 0s 0us/step
# 25000 train sequences
# 25000 test sequences
# Pad sequences (samples x time)
# 25000 train sequences
# 25000 test sequences
# Pad sequences (samples x time)
# 25000 train sequences
# 25000 test sequences
# Pad sequences (samples x time)
# x_train shape: (25000, 100)
# x_test shape: (25000, 100)
# Build model...
# 25000 train sequences
# 25000 test sequences
# Pad sequences (samples x time)
# x_train shape: (25000, 100)
# x_test shape: (25000, 100)
# Build model...
# Train...
# x_train shape: (25000, 100)
# x_test shape: (25000, 100)
# Build model...
# x_train shape: (25000, 100)
# x_test shape: (25000, 100)
# Build model...
# Train...
# Train...
# Train...
# Train on 25000 samples, validate on 25000 samples
# Train on 25000 samples, validate on 25000 samples
# Train on 25000 samples, validate on 25000 samples
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/1
# Epoch 1/1
# Epoch 1/1
# Epoch 1/1
#
#    32/25000 [..............................] - ETA: 10:35 - loss: 0.6929 - acc: 0.5000
#    32/25000 [..............................] - ETA: 10:34 - loss: 0.6929 - acc: 0.5000
#    32/25000 [..............................] - ETA: 10:49 - loss: 0.6929 - acc: 0.5000
#    32/25000 [..............................] - ETA: 10:49 - loss: 0.6929 - acc: 0.5000
#    64/25000 [..............................] - ETA: 7:31 - loss: 0.6965 - acc: 0.4531
#    64/25000 [..............................] - ETA: 7:30 - loss: 0.6965 - acc: 0.4531
#    64/25000 [..............................] - ETA: 7:33 - loss: 0.6965 - acc: 0.4531
#    64/25000 [..............................] - ETA: 7:33 - loss: 0.6965 - acc: 0.4531
#    96/25000 [..............................] - ETA: 6:29 - loss: 0.6983 - acc: 0.4167
#    96/25000 [..............................] - ETA: 6:28 - loss: 0.6983 - acc: 0.4167
#    96/25000 [..............................] - ETA: 6:32 - loss: 0.6983 - acc: 0.4167
#    96/25000 [..............................] - ETA: 6:32 - loss: 0.6983 - acc: 0.4167
#   128/25000 [..............................] - ETA: 6:06 - loss: 0.6955 - acc: 0.4688
# 23136/25000 [==========================>...] - ETA: 3s
# 24544/25000 [============================>.] - ETA: 0s
# 24288/25000 [============================>.] - ETA: 1s
# 23968/25000 [===========================>..] - ETA: 2s
# 23168/25000 [==========================>...] - ETA: 3s
# 24576/25000 [============================>.] - ETA: 0s
# 24320/25000 [============================>.] - ETA: 1s
# 24000/25000 [===========================>..] - ETA: 1s
# 23200/25000 [==========================>...] - ETA: 3s
# 24608/25000 [============================>.] - ETA: 0s
# 24352/25000 [============================>.] - ETA: 1s
# 24032/25000 [===========================>..] - ETA: 1s
# 23232/25000 [==========================>...] - ETA: 3s
# 24640/25000 [============================>.] - ETA: 0s
# 24384/25000 [============================>.] - ETA: 1s
# 23264/25000 [==========================>...] - ETA: 3s
# 24064/25000 [===========================>..] - ETA: 1s
# 24672/25000 [============================>.] - ETA: 0s
# 24416/25000 [============================>.] - ETA: 1s
# 24096/25000 [===========================>..] - ETA: 1s
# 23296/25000 [==========================>...] - ETA: 3s
# 24704/25000 [============================>.] - ETA: 0s
# 24448/25000 [============================>.] - ETA: 1s
# 24128/25000 [===========================>..] - ETA: 1s
# 23328/25000 [==========================>...] - ETA: 3s
# 24736/25000 [============================>.] - ETA: 0s
# 24480/25000 [============================>.] - ETA: 1s
# 24160/25000 [===========================>..] - ETA: 1s
# 23360/25000 [===========================>..] - ETA: 3s
# 24768/25000 [============================>.] - ETA: 0s
# 24512/25000 [============================>.] - ETA: 0s
# 24192/25000 [============================>.] - ETA: 1s
# 23392/25000 [===========================>..] - ETA: 3s
# 24800/25000 [============================>.] - ETA: 0s
# 24544/25000 [============================>.] - ETA: 0s
# 24224/25000 [============================>.] - ETA: 1s
# 23424/25000 [===========================>..] - ETA: 3s
# 24832/25000 [============================>.] - ETA: 0s
# 24576/25000 [============================>.] - ETA: 0s
# 24256/25000 [============================>.] - ETA: 1s
# 23456/25000 [===========================>..] - ETA: 3s
# 24864/25000 [============================>.] - ETA: 0s
# 24608/25000 [============================>.] - ETA: 0s
# 24288/25000 [============================>.] - ETA: 1s
# 23488/25000 [===========================>..] - ETA: 3s
# 24896/25000 [============================>.] - ETA: 0s
# 24640/25000 [============================>.] - ETA: 0s
# 24320/25000 [============================>.] - ETA: 1s
# 23520/25000 [===========================>..] - ETA: 2s
# 24928/25000 [============================>.] - ETA: 0s
# 24672/25000 [============================>.] - ETA: 0s
# 24352/25000 [============================>.] - ETA: 1s
# 23552/25000 [===========================>..] - ETA: 2s
# 24960/25000 [============================>.] - ETA: 0s
# 24704/25000 [============================>.] - ETA: 0s
# 24384/25000 [============================>.] - ETA: 1s
# 23584/25000 [===========================>..] - ETA: 2s
# 24992/25000 [============================>.] - ETA: 0s
# 24736/25000 [============================>.] - ETA: 0s
# 23616/25000 [===========================>..] - ETA: 2s
# 25000/25000 [==============================] - 49s 2ms/step
# Test score: 0.414263581314
# Test accuracy: 0.81944
#
# 24416/25000 [============================>.] - ETA: 1s
# 24768/25000 [============================>.] - ETA: 0s
# 23648/25000 [===========================>..] - ETA: 2s
# 24448/25000 [============================>.] - ETA: 1s
# 24800/25000 [============================>.] - ETA: 0s
# 23680/25000 [===========================>..] - ETA: 2s
# 24480/25000 [============================>.] - ETA: 1s
# 24832/25000 [============================>.] - ETA: 0s
# 23712/25000 [===========================>..] - ETA: 2s
# 24512/25000 [============================>.] - ETA: 0s
# 24864/25000 [============================>.] - ETA: 0s
# 23744/25000 [===========================>..] - ETA: 2s
# 24544/25000 [============================>.] - ETA: 0s
# 24896/25000 [============================>.] - ETA: 0s
# 23776/25000 [===========================>..] - ETA: 2s
# 24576/25000 [============================>.] - ETA: 0s
# 24928/25000 [============================>.] - ETA: 0s
# 23808/25000 [===========================>..] - ETA: 2s
# 24608/25000 [============================>.] - ETA: 0s
# 24960/25000 [============================>.] - ETA: 0s
# 23840/25000 [===========================>..] - ETA: 2s
# 24640/25000 [============================>.] - ETA: 0s
# 24992/25000 [============================>.] - ETA: 0s
# 23872/25000 [===========================>..] - ETA: 2s
# 24672/25000 [============================>.] - ETA: 0s
# 25000/25000 [==============================] - 50s 2ms/step
# Test score: 0.414263553982
# Test accuracy: 0.81944
#
# 23904/25000 [===========================>..] - ETA: 2s
# 24704/25000 [============================>.] - ETA: 0s
# 23936/25000 [===========================>..] - ETA: 2s
# 24736/25000 [============================>.] - ETA: 0s
# 23968/25000 [===========================>..] - ETA: 2s
# 24768/25000 [============================>.] - ETA: 0s
# 24000/25000 [===========================>..] - ETA: 2s
# 24800/25000 [============================>.] - ETA: 0s
# 24032/25000 [===========================>..] - ETA: 1s
# 24832/25000 [============================>.] - ETA: 0s
# 24064/25000 [===========================>..] - ETA: 1s
# 24864/25000 [============================>.] - ETA: 0s
# 24096/25000 [===========================>..] - ETA: 1s
# 24896/25000 [============================>.] - ETA: 0s
# 24128/25000 [===========================>..] - ETA: 1s
# 24928/25000 [============================>.] - ETA: 0s
# 24160/25000 [===========================>..] - ETA: 1s
# 24960/25000 [============================>.] - ETA: 0s
# 24192/25000 [============================>.] - ETA: 1s
# 24992/25000 [============================>.] - ETA: 0s
# 24224/25000 [============================>.] - ETA: 1s
# 25000/25000 [==============================] - 50s 2ms/step
# Test score: 0.414263550282
# Test accuracy: 0.81944
#
# 24256/25000 [============================>.] - ETA: 1s
# 24288/25000 [============================>.] - ETA: 1s
# 24320/25000 [============================>.] - ETA: 1s
# 24352/25000 [============================>.] - ETA: 1s
# 24384/25000 [============================>.] - ETA: 1s
# 24416/25000 [============================>.] - ETA: 1s
# 24448/25000 [============================>.] - ETA: 1s
# 24480/25000 [============================>.] - ETA: 1s
# 24512/25000 [============================>.] - ETA: 0s
# 24544/25000 [============================>.] - ETA: 0s
# 24576/25000 [============================>.] - ETA: 0s
# 24608/25000 [============================>.] - ETA: 0s
# 24640/25000 [============================>.] - ETA: 0s
# 24672/25000 [============================>.] - ETA: 0s
# 24704/25000 [============================>.] - ETA: 0s
# 24736/25000 [============================>.] - ETA: 0s
# 24768/25000 [============================>.] - ETA: 0s
# 24800/25000 [============================>.] - ETA: 0s
# 24832/25000 [============================>.] - ETA: 0s
# 24864/25000 [============================>.] - ETA: 0s
# 24896/25000 [============================>.] - ETA: 0s
# 24928/25000 [============================>.] - ETA: 0s
# 24960/25000 [============================>.] - ETA: 0s
# 24992/25000 [============================>.] - ETA: 0s
# 25000/25000 [==============================] - 51s 2ms/step
# Test score: 0.41426356205
# Test accuracy: 0.81944
#
# stderr.txt content:
# Unexpected end of /proc/mounts line `overlay / overlay rw,relatime,lowerdir=/data/docker/overlay2/l/ONK5GR4VWKHKRSNDGC6FNHILOP:/data/docker/overlay2/l/4FPPFJAKAHHLPV4IUG3XYXSQOC:/data/docker/overlay2/l/P3YG5QNWWEN4GTBVQXA45ZMCVO:/data/docker/overlay2/l/7ETI3SIRWVXFTEZZCPKXIEWOOL:/data/docker/overlay2/l/BHXA2ONBJPKXSVTMWANVJWXI4Y:/data/docker/overlay2/l/MICSF2HVZ6FHIQT6Z2JEBEF36J:/data/docker/overlay2/l/EYFLYANDT2N77FSKCUQJJ456TG:/data/docker/overlay2/l/EOXSUOI4WSBO4GOSTUKJHY3HUB:/data/docker/overlay2/l/3XDZLNLCSE5FZTZYDKNBQ3J7EV:/data/docker/'
# Unexpected end of /proc/mounts line `overlay2/l/HNOD5QAO7MKSVH2XGD6BT5JB7E:/data/docker/overlay2/l/32SX2QIAABSK7PYYPANHJZOSVZ:/data/docker/overlay2/l/FWSZ3OANLWXP54CMFEB5SFNJSI:/data/docker/overlay2/l/CXFU7ABMA5G6AKC3ZHFC2KLCO3:/data/docker/overlay2/l/656X2IDSZWB6WXXGYPPY5IMFJU:/data/docker/overlay2/l/A7UGW35SJPYZSVCWD7U4JCV75H:/data/docker/overlay2/l/XU2CKZO6WSQSZYPIIYUBIACLOC:/data/docker/overlay2/l/DV6L7AEIBRACQMFCLMM6N3VIFV:/data/docker/overlay2/l/UAFYW2CXMWTGAWVU452BXSNSIG:/data/docker/overlay2/l/HSX2PHMVQ76KNIRHN4NLPLXXDS,upperdir=/data'
# Warning: Permanently added '[10.0.0.5]:23' (ECDSA) to the list of known hosts.
# Warning: Permanently added '[10.0.0.6]:23' (ECDSA) to the list of known hosts.
# Unexpected end of /proc/mounts line `overlay / overlay rw,relatime,lowerdir=/data/docker/overlay2/l/UHRHOCQEJFOW62LCBFQLIYJSI6:/data/docker/overlay2/l/TFMNO37DHKI5UNHT5SHTC7OALU:/data/docker/overlay2/l/4K5OYQ5JQVWROX6GXX3WRUXEZ2:/data/docker/overlay2/l/IPR55EXQLN6QXPSWGTZVHFN3W3:/data/docker/overlay2/l/NYJ6HCYQZUS3BDVCJ66GMKMGVP:/data/docker/overlay2/l/AZFXZDNB773YS45R6QYL4MCWA6:/data/docker/overlay2/l/5N3W4KYC2JWWTP4UQU3E7GKHU4:/data/docker/overlay2/l/XR2A4BGQSHXHMKNARCSWWEZ6TA:/data/docker/overlay2/l/FPILVANEOCDMKCN4AGPKR54HR4:/data/docker/'
# Unexpected end of /proc/mounts line `overlay2/l/MLGVM24YF7AMCB3ERMQKNMJUWN:/data/docker/overlay2/l/EZVPMB2JWEYTFWCGBMOHPAIPLX:/data/docker/overlay2/l/XSTR4AS6FDBZ4IK2ONEYCU5REQ:/data/docker/overlay2/l/FOKLWLG5IQZU5TT6SEZ7SHPUZH:/data/docker/overlay2/l/YVMR3SN6QUS7XW7FPTRNYQZCDO:/data/docker/overlay2/l/6QZ5VDM5X5HSJIGJBKIHDQSU5T:/data/docker/overlay2/l/CK6F3LIN3WA3DDMDF3OWG6PEI7:/data/docker/overlay2/l/KWY7KTALDBLU6RU2NHEPQVKZM3:/data/docker/overlay2/l/EDKUT2TUU2NV5DQ4AJWYBGIIJC:/data/docker/overlay2/l/A54IURXNUJSXSFOPRZMCSOHOIS,upperdir=/data'
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# Using TensorFlow backend.
# 2018-01-26 17:30:00.656113: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-01-26 17:30:00.656528: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-01-26 17:30:00.658648: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-01-26 17:30:00.656949: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-01-26 17:30:00.903121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 06db:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-01-26 17:30:00.903164: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1120] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: Tesla K80, pci bus id: 06db:00:00.0, compute capability: 3.7)
# 2018-01-26 17:30:00.898048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 54f8:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-01-26 17:30:00.898090: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1120] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: Tesla K80, pci bus id: 54f8:00:00.0, compute capability: 3.7)
# 2018-01-26 17:30:00.913456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0637:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-01-26 17:30:00.913499: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1120] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: Tesla K80, pci bus id: 0637:00:00.0, compute capability: 3.7)
# 2018-01-26 17:30:00.917879: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 1807:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-01-26 17:30:00.917913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1120] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: Tesla K80, pci bus id: 1807:00:00.0, compute capability: 3.7)
# [d7a020c29eb74b5aa6c9b6c5b2279fc6000000:01218] 3 more processes have sent help message help-mpi-btl-base.txt / btl:no-nics
# [d7a020c29eb74b5aa6c9b6c5b2279fc6000000:01218] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages

# %% [markdown]
# ### Delete the Job

# %%
client.jobs.delete(cfg.resource_group, job_name)

# %% [markdown]
# ### Delete the Cluster
# When you are finished with the sample and don't want to submit any more jobs you can delete the cluster using the following code.

# %%
client.clusters.delete(cfg.resource_group, cluster_name)

# %% [markdown]
# ### Delete File Share
# When you are finished with the sample and don't want to submit any more jobs you can delete the file share completely with all files using the following code.

# %%
service = FileService(cfg.storage_account_name, cfg.storage_account_key)
service.delete_share(azure_file_share_name)
# Out:
# True
